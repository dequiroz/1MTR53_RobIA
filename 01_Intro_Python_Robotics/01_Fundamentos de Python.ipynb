# %% [markdown]
# <a href="https://colab.research.google.com/github/dequiroz/1MTR53_RobIA/blob/main/01_Intro_Python_Robotics/01_Fundamentos%20de%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1FsTa2YzWwxY-HBkd2EOXAlkPJ1zpikWv" alt="drawing" width="150"/>
#
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1VBn7nKlruxCPLHH_UuD8B2pkvKP7JLRd" alt="drawing" width="800"/>
#
#
# </br>
#
# <img src="https://drive.google.com/uc?export=view&id=1tpg1CJh4or-VMrY-Qip25hgedgwy1Y8-" alt="drawing" width="800"/>
# </p>
#
#
# # Fundamentos de Python y Lógica Algorítmica para Mecatrónica
# * **Responsable del material:** Diego Quiroz Velasquez
# * Pontificia Universidad Católica del Perú
# * Sección Ingeniería Mecatrónica
#
# ---
# > **Descripción:** > Este cuaderno interactivo constituye el primer módulo de nivelación para el curso de Robótica e Inteligencia Artificial. Su propósito pedagógico es facilitar la transición sintáctica desde lenguajes compilados (C/C++) hacia Python, reforzando la lógica algorítmica, las estructuras de control y la gestión de structuras de datos aplicadas a la lectura de sensores y el control de actuadores en la Ingeniería Mecatrónica.
#
# <details>
# <summary><b>📋 Historial de Versiones del Documento (Hacer clic para desplegar)</b></summary>
#
# <br>
#
# | Versión | Fecha | Autor / Rol | Descripción del Cambio |
# | :---: | :---: | :--- | :--- |
# | **v1.0** | 29/07/2026 | Diego Quiroz | Estructuración inicial del material didáctico y sintaxis básica. |
#
# ---
# </details>
# <br>
# <img src="https://drive.google.com/uc?export=view&id=1vgFoFHEKMN0WcAFlKS2hPMg2KuBm3sp9" alt="drawing"/>

# %% [markdown]
# ## Introducción
#
# El presente cuaderno interactivo está diseñado para establecer los fundamentos del lenguaje Python, orientado específicamente a aplicaciones de Robótica e Inteligencia Artificial (IA).
#
# Dado su conocimiento previo en lenguajes compilados como C y C++, notarán que Python prioriza la legibilidad y la rapidez en la creación de prototipos. Las diferencias principales radican en:
# 1. **Ausencia de llaves `{ }`:** Los bloques de código se definen estrictamente por la **indentación** (espacios al inicio de la línea).
# 2. **Tipado dinámico:** No es necesario declarar si una variable es `int`, `float` o `char`; el intérprete lo asigna automáticamente.
# 3. **Ausencia de punto y coma `;`:** Las instrucciones terminan con un salto de línea estándar.

# %%
# ==============================================================================
# 1. SINTAXIS BÁSICA Y TIPADO DINÁMICO
# ==============================================================================

# En C/C++, la declaración exige el tipo: float voltaje_bateria = 12.5;
# En Python, la asignación es directa:

voltaje_bateria = 12.5      # Tipo flotante (float)
motores_activos = 4         # Tipo entero (int)
modo_autonomo = True        # Tipo booleano (bool). Nótese la primera letra en mayúscula.
identificador = "RBT-Alpha" # Tipo cadena de caracteres (str)

# La función type() permite identificar el tipo de dato asignado.
# Utilizamos "f-strings" (f"...") para concatenar texto y variables fácilmente,
# reemplazando la complejidad del printf() de C.

print("--- Inicialización del Sistema ---")
print(f"Robot: {identificador} | Voltaje: {voltaje_bateria}V")
print(f"El tipo de dato de 'motores_activos' es: {type(motores_activos)}")

# PRECAUCIÓN ALGORÍTMICA: Al no tener un tipo fijo, una variable puede cambiar
# su naturaleza durante la ejecución. Esto debe evitarse en sistemas de control
# para mantener la estabilidad del código.
# Out:
# --- Inicialización del Sistema ---
# Robot: RBT-Alpha | Voltaje: 12.5V
# El tipo de dato de 'motores_activos' es: <class 'int'>

# %% [markdown]
# ## 2. Álgebra de Boole y Toma de Decisiones
#
# El diseño de algoritmos reactivos requiere la evaluación constante del entorno mediante sensores. En C, los operadores lógicos son matemáticos (`&&`, `||`, `!`). Python utiliza un enfoque de lenguaje natural (`and`, `or`, `not`), lo que facilita la transcripción directa desde un diagrama de flujo o seudocódigo lógico.
#
# Leer y revisar el siguiente código y notar las similitudes del codigo python con el seudocódigo y el lenguaje natural.

# %%
# ==============================================================================
# 2. OPERADORES LÓGICOS Y CONDICIONALES (IF - ELIF - ELSE)
# ==============================================================================

# Variables simuladas a partir de la lectura de un sensor ultrasónico (en cm)
distancia_frontal = 12.0
distancia_lateral = 45.0
bateria_critica = False

print("\n--- Subsistema de Navegación y Evasión ---")

# Evaluación lógica combinada.
# La indentación define qué código se ejecuta si se cumple la condición.

if distancia_frontal < 15.0 and distancia_lateral < 15.0:
    # Ambas condiciones deben cumplirse (AND)
    print("ALERTA: Entorno cerrado. Comandos: Detener motores y emitir alarma.")
    velocidad = 0.0

elif distancia_frontal < 15.0 or distancia_lateral < 15.0:
    # Al menos una condición se cumple (OR) - 'elif' equivale a 'else if' en C
    print("PRECAUCIÓN: Obstáculo detectado en un eje. Comandos: Reducir velocidad al 30%.")
    velocidad = 0.3

else:
    # Ninguna de las anteriores se cumplió
    print("VÍA LIBRE: Sin obstáculos cercanos. Comandos: Velocidad nominal.")
    velocidad = 1.0

# Uso del operador de negación (NOT) equivalente a '!' en C
if not bateria_critica:
    print(f"Estado de energía óptimo. Ejecutando motores a {velocidad * 100}% de potencia.")
# Out:
# --- Subsistema de Navegación y Evasión ---
# PRECAUCIÓN: Obstáculo detectado en un eje. Comandos: Reducir velocidad al 30%.
# Estado de energía óptimo. Ejecutando motores a 30.0% de potencia.

# %% [markdown]
# ## 3. Construcción de Algoritmos Iterativos (Bucles)
#
# Los lazos de control cerrados y el procesamiento de señales dependen de iteraciones constantes. Python simplifica los bucles clásicos:
# *   **Bucle `while`:** Ideal para procesos que deben ejecutarse continuamente hasta que una condición física o lógica cambie.
# *   **Bucle `for`:** A diferencia de C, donde se requiere un contador explícito (`for(int i=0; i<N; i++)`), en Python el `for` itera directamente sobre secuencias o rangos predefinidos.

# %%
# ==============================================================================
# 3. PATRONES ITERATIVOS: WHILE Y FOR
# ==============================================================================

print("\n--- Secuencia de Calibración (Uso de 'while') ---")

# Patrón algorítmico: Bucle con condición de salida
presion_sistema = 0.0
presion_deseada = 2.5
ciclo = 0

# Se ejecuta mientras la presión sea menor a la deseada
while presion_sistema < presion_deseada:
    ciclo += 1                # Operador de incremento (equivale a ciclo = ciclo + 1)
    presion_sistema += 0.75   # Simulamos la acción de una bomba
    print(f"Ciclo {ciclo} -> Presión actual: {presion_sistema:.2f} atm")

print("Calibración del sistema hidráulico completada.")


print("\n--- Barrido de Actuador (Uso de 'for') ---")

# La función range(inicio, fin, paso) genera una secuencia automática.
# El 'fin' es un límite excluyente (llega hasta fin - 1).
# Este bucle va de 0 a 40 grados, con incrementos de 10.

for angulo in range(0, 50, 10):
    print(f"Enviando señal PWM: Posicionando servomotor en {angulo}°")
# Out:
# --- Secuencia de Calibración (Uso de 'while') ---
# Ciclo 1 -> Presión actual: 0.75 atm
# Ciclo 2 -> Presión actual: 1.50 atm
# Ciclo 3 -> Presión actual: 2.25 atm
# Ciclo 4 -> Presión actual: 3.00 atm
# Calibración del sistema hidráulico completada.
#
# --- Barrido de Actuador (Uso de 'for') ---
# Enviando señal PWM: Posicionando servomotor en 0°
# Enviando señal PWM: Posicionando servomotor en 10°
# Enviando señal PWM: Posicionando servomotor en 20°
# Enviando señal PWM: Posicionando servomotor en 30°
# Enviando señal PWM: Posicionando servomotor en 40°

# %% [markdown]
# ## 4. Estructuras de Datos, Indexación y Procesamiento
#
# En mecatrónica es ineficiente crear variables individuales para múltiples datos (`sensor1`, `sensor2`, `sensor3`). Para organizar la información, Python ofrece tres estructuras fundamentales:
#
# 1.  **Listas (`[ ]`):** Arreglos dinámicos y mutables. Fundamentales para almacenar un flujo temporal de datos (ej. histórico de sensores).
# 2.  **Tuplas (`( )`):** Colecciones inmutables. Se usan para datos que no deben alterarse accidentalmente, como coordenadas $(x, y, z)$.
# 3.  **Diccionarios (`{ }`):** Estructuras de clave-valor. Ideales para mapear el estado completo de un sistema.
#
# **Nota sobre indexación:** Al igual que en C, el primer elemento de una estructura siempre ocupa la **posición 0**.

# %%
# ==============================================================================
# 4. ESTRUCTURAS DE DATOS Y PATRONES ALGORÍTMICOS
# ==============================================================================

print("\n--- 4.1 Listas e Indexación ---")
# Arreglo con lecturas consecutivas de un sensor LiDAR (en metros)
lecturas_lidar = [1.2, 1.5, 2.8, 3.1, 1.4]
print(f"Matriz de datos LiDAR: {lecturas_lidar}")

# Acceso al primer elemento (Índice 0)
print(f"Primera lectura registrada: {lecturas_lidar[0]} m")

# Slicing (Particionamiento): Extraer una sub-matriz de datos
# Extrae desde el índice 1 hasta el 3 (el límite superior 4 es excluyente)
segmento_central = lecturas_lidar[1:4]
print(f"Sub-segmento de datos (índices 1, 2, 3): {segmento_central}")

# Patrón algorítmico: Acumulador
# Recorremos la lista para aplicar un filtro de promedio simple
suma_lecturas = 0.0
for valor in lecturas_lidar:
    suma_lecturas += valor

promedio = suma_lecturas / len(lecturas_lidar) # len() obtiene la longitud del arreglo
print(f"El promedio de las mediciones es: {promedio:.2f} m")


print("\n--- 4.2 Tuplas (Estructuras Inmutables) ---")
# Representan estados físicos invariables en una iteración, como el Origen.
origen_cartesiano = (0.0, 0.0, 0.0)
print(f"Coordenadas de la base del robot: {origen_cartesiano}")
# origen_cartesiano[0] = 1.0  # Descomentar esto causaría un error, la tupla protege el dato.


print("\n--- 4.3 Diccionarios (Mapeo de Estados) ---")
# Agrupan atributos heterogéneos de forma semántica, similar a un 'struct' en C.
telemetria = {
    "rpm_motor1": 1200,
    "rpm_motor2": 1195,
    "temperatura_chasis": 35.5,
    "estado_comunicacion": "OK"
}

print("Datos de telemetría extraídos del diccionario:")
print(f"Velocidad Motor 1: {telemetria['rpm_motor1']} RPM")
print(f"Temperatura actual: {telemetria['temperatura_chasis']} °C")
# Out:
# --- 4.1 Listas e Indexación ---
# Matriz de datos LiDAR: [1.2, 1.5, 2.8, 3.1, 1.4]
# Primera lectura registrada: 1.2 m
# Sub-segmento de datos (índices 1, 2, 3): [1.5, 2.8, 3.1]
# El promedio de las mediciones es: 2.00 m
#
# --- 4.2 Tuplas (Estructuras Inmutables) ---
# Coordenadas de la base del robot: (0.0, 0.0, 0.0)
#
# --- 4.3 Diccionarios (Mapeo de Estados) ---
# Datos de telemetría extraídos del diccionario:
# Velocidad Motor 1: 1200 RPM
# Temperatura actual: 35.5 °C

# %% [markdown]
# ## 5. Ejercicios Prácticos de Programación
#
# La siguiente sección contiene problemas propuestos para afianzar la lógica computacional en Python. Se provee la estructura base del código; su tarea como estudiante de ingeniería es implementar la lógica algorítmica solicitada dentro de las celdas correspondientes.

# %% [markdown]
# ### Ejercicio 1: Sistema de Seguridad Térmica (Lógica Condicional)
# **Contexto:** Un manipulador robótico industrial cuenta con un sensor de temperatura en sus servomotores.
# **Requerimiento:** Diseñe un algoritmo que evalúe la temperatura actual y cambie el estado del sistema según las siguientes reglas:
# *   Si la temperatura es menor o igual a **45.0°C**, el estado debe ser `"ÓPTIMO"`.
# *   Si la temperatura está entre **45.0°C** (excluyente) y **75.0°C** (incluyente), el estado debe ser `"ADVERTENCIA: Activar refrigeración"`.
# *   Si la temperatura supera los **75.0°C**, el estado debe ser `"CRÍTICO: Parada de emergencia"`.

# %%
# --- INICIO DEL EJERCICIO 1 ---
temperatura_actual = 68.5
estado_sistema = ""

# TODO: Implemente su lógica condicional (if-elif-else) aquí

# --- FIN DEL EJERCICIO 1 ---

print(f"Temperatura: {temperatura_actual}°C -> Estado: {estado_sistema}")

# %% [markdown]
# ### Ejercicio 2: Procesamiento de Telemetría (Bucles y Listas)
# **Contexto:** Un vehículo autónomo submarino (AUV) registra su profundidad en metros cada 10 segundos. Debido a fallos de comunicación o ruido térmico, a veces se registran valores negativos (lo cual es físicamente imposible para este sensor en particular).
# **Requerimiento:**
# 1. Recorra la lista `lecturas_profundidad`.
# 2. Utilice un bucle para filtrar los datos: si el valor es mayor o igual a cero, añádalo a una nueva lista llamada `lecturas_validas`.
# 3. Calcule y muestre el promedio de las lecturas válidas.

# %%
# --- INICIO DEL EJERCICIO 2 ---
lecturas_profundidad = [12.5, 13.0, -2.5, 14.1, 15.0, -99.9, 14.5]
lecturas_validas = []

# TODO 1: Implemente un bucle for para filtrar los valores válidos (>= 0)
# Pista: Use el método .append() de las listas


# TODO 2: Calcule el promedio de los elementos en 'lecturas_validas'
promedio_profundidad = 0.0


# --- FIN DEL EJERCICIO 2 ---

print(f"Lecturas crudas: {lecturas_profundidad}")
print(f"Lecturas filtradas: {lecturas_validas}")
print(f"Profundidad promedio: {promedio_profundidad:.2f} m")

# %% [markdown]
# ### Ejercicio 3: Actualización de Estado (Diccionarios)
# **Contexto:** El estado general de un dron se almacena en un diccionario. Durante el vuelo, el dron recibe un comando desde la estación terrena para cambiar su modo de operación y registra un consumo de batería.
# **Requerimiento:**
# 1. Modifique el valor de la clave `"modo_vuelo"` a `"Retorno a Casa"`.
# 2. Disminuya el valor de la clave `"bateria_porcentaje"` en un **15%** respecto a su valor actual.
# 3. Agregue una nueva clave llamada `"coordenada_destino"` con el valor en tupla `(10.5, 22.1, 0.0)`.

# %%
# --- INICIO DEL EJERCICIO 3 ---
estado_dron = {
    "id": "DRN-X1",
    "modo_vuelo": "Exploración",
    "bateria_porcentaje": 80.0,
    "altitud_m": 120.5
}

print("Estado inicial:")
print(estado_dron)

# TODO 1: Actualizar el modo de vuelo


# TODO 2: Reducir la batería en 15.0


# TODO 3: Agregar la tupla de coordenadas de destino


# --- FIN DEL EJERCICIO 3 ---

print("\nEstado actualizado tras comando de base:")
print(estado_dron)

# %% [markdown]
# ### Ejercicio 4: Lazo de Control de Aproximación (Bucle `while`)
# **Contexto:** Un robot móvil diferencial tiene la tarea de acercarse a una estación de carga. El robot utiliza un sensor láser para medir la distancia restante. Por seguridad mecánica, el robot debe detenerse cuando se encuentre a **0.5 metros o menos** de la estación.
# **Requerimiento:**
# 1. Diseñe un lazo de control utilizando un bucle `while`.
# 2. En cada iteración del bucle, simule que el robot avanza reduciendo la `distancia_actual` en **0.8 metros**.
# 3. Imprima la distancia en cada paso para observar la aproximación.
# 4. Una vez que el bucle termine (condición de parada alcanzada), imprima un mensaje confirmando el acople exitoso.

# %%
# --- INICIO DEL EJERCICIO 4 ---
distancia_actual = 5.0  # metros
distancia_parada = 0.5  # metros
iteracion = 0

print("Iniciando maniobra de aproximación...")

# TODO: Implemente el bucle while que se ejecute mientras la distancia_actual
# sea estrictamente mayor a la distancia_parada.
# Dentro del bucle:
# 1. Incremente la variable 'iteracion' en 1.
# 2. Reste 0.8 a 'distancia_actual'.
# 3. Imprima el estado usando: print(f"Paso {iteracion}: Distancia restante = {distancia_actual:.2f} m")


# --- FIN DEL EJERCICIO 4 ---

print("Maniobra finalizada. Robot acoplado a la estación de carga de forma segura.")
